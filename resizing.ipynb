# %% [markdown]
# # upscale resolution

# %%
import numpy as np
import cv2
from helper import *

# %%
img = cv2.imread("./result.png")

# %%
show_img(img)
# Out:
# Image size:(461, 471, 3)

# %%
small = cv2.resize(img, (200, 200), interpolation=cv2.INTER_AREA)
show_img(small)
# Out:
# Image size:(200, 200, 3)

# %%
large = cv2.resize(img, (12000, 12000), interpolation=cv2.INTER_NEAREST)
show_img(large)
# Out:
# Image size:(12000, 12000, 3)

# %%
cv2.imwrite("large.png", large)
# Out:
# True
